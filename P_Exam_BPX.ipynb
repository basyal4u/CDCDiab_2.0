# %% [markdown]
# #  Processing Examination - Blood Pressure File (BP)

# %%
import numpy as np
import pandas as pd
import glob 
import os
import sys

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Code'

# %%
# Select working directory
path = 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination'
#%cd /Users/elgayaro/Main/Research/Healthcare/CDC-NHANES/Data/07-08/Examination

# %%
allFiles = glob.glob(os.path.join(path,"*.XPT"))
print(allFiles)
# Out:
# ['C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUXAR_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUXTYM_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\BMX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\BPX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\DXXFEM_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\DXXSPN_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\ENX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OHX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OPXFDT_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OPXRET_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\SPX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\VIX_E.XPT']

# %%
BPX = pd.read_sas('C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\BPX_E.XPT', index='SEQN')
BPX.shape
# Out:
# (9762, 26)

# %%
A = set(BPX.columns)
print(sorted(A))
# Out:
# ['BPAARM', 'BPACSZ', 'BPAEN1', 'BPAEN2', 'BPAEN3', 'BPAEN4', 'BPQ150A', 'BPQ150B', 'BPQ150C', 'BPQ150D', 'BPXCHR', 'BPXDI1', 'BPXDI2', 'BPXDI3', 'BPXDI4', 'BPXML1', 'BPXPLS', 'BPXPTY', 'BPXPULS', 'BPXSY1', 'BPXSY2', 'BPXSY3', 'BPXSY4', 'PEASCCT1', 'PEASCST1', 'PEASCTM1']

# %%
A = set(BPX.columns)
print(A)
# Out:
# {'PEASCCT1', 'BPXCHR', 'BPQ150C', 'BPACSZ', 'BPXPTY', 'BPAEN2', 'BPXSY3', 'BPXDI4', 'BPQ150B', 'PEASCST1', 'BPAEN1', 'BPXDI3', 'BPQ150D', 'BPAEN4', 'BPXPULS', 'PEASCTM1', 'BPXSY2', 'BPAEN3', 'BPXDI2', 'BPQ150A', 'BPXDI1', 'BPXML1', 'BPXPLS', 'BPXSY1', 'BPAARM', 'BPXSY4'}

# %%
BPX.dtypes
# Out:
# PEASCST1    float64
# PEASCTM1    float64
# PEASCCT1    float64
# BPXCHR      float64
# BPQ150A     float64
# BPQ150B     float64
# BPQ150C     float64
# BPQ150D     float64
# BPAARM      float64
# BPACSZ      float64
# BPXPLS      float64
# BPXPULS     float64
# BPXPTY      float64
# BPXML1      float64
# BPXSY1      float64
# BPXDI1      float64
# BPAEN1      float64
# BPXSY2      float64
# BPXDI2      float64
# BPAEN2      float64
# BPXSY3      float64
# BPXDI3      float64
# BPAEN3      float64
# BPXSY4      float64
# BPXDI4      float64
# BPAEN4      float64
# dtype: object

# %%
BPX.filter(like='BPX').notnull().count().head()
# Out:
# BPXCHR     9762
# BPXPLS     9762
# BPXPULS    9762
# BPXPTY     9762
# BPXML1     9762
# dtype: int64

# %%
BPX.filter(like="BPX").head()
# Out:
#          BPXCHR  BPXPLS  BPXPULS  BPXPTY  BPXML1  BPXSY1  BPXDI1  BPXSY2  \
# SEQN
# 41475.0     NaN    66.0      1.0     1.0   150.0   128.0    64.0   122.0
# 41476.0    72.0     NaN      1.0     NaN     NaN     NaN     NaN     NaN
# 41477.0     NaN    78.0      1.0     1.0   180.0   144.0    60.0   148.0
# 41478.0   120.0     NaN      1.0     NaN     NaN     NaN     NaN     NaN
# 41479.0     NaN    62.0      1.0     1.0   140.0   112.0    70.0   108.0
#
#          BPXDI2  BPXSY3  BPXDI3  BPXSY4  BPXDI4
# SEQN
# 41475.0    60.0   120.0    58.0     NaN     NaN
# 41476.0     NaN     NaN     NaN     NaN     NaN
# 41477.0    60.0   142.0    38.0     NaN     NaN
# 41478.0     NaN     NaN     NaN     NaN     NaN
# 41479.0    66.0   106.0    66.0     NaN     NaN

# %%
BPX.describe().T
# Out:
#            count        mean         std           min    25%    50%    75%  \
# PEASCST1  9762.0    1.080209    0.388888  1.000000e+00    1.0    1.0    1.0
# PEASCTM1  9369.0  492.577436  221.587772  3.000000e+00  435.0  536.0  623.0
# PEASCCT1   405.0   52.325926   20.187793  2.000000e+00   56.0   56.0   56.0
# BPXCHR    2016.0  106.307540   20.990856  5.397605e-79   92.0  106.0  118.0
# BPQ150A   7370.0    1.772185    0.419451  1.000000e+00    2.0    2.0    2.0
# BPQ150B   7370.0    1.999593    0.020173  1.000000e+00    2.0    2.0    2.0
# BPQ150C   7370.0    1.993351    0.081273  1.000000e+00    2.0    2.0    2.0
# BPQ150D   7370.0    1.981004    0.136520  1.000000e+00    2.0    2.0    2.0
# BPAARM    7370.0    1.012483    0.240677  1.000000e+00    1.0    1.0    1.0
# BPACSZ    7353.0    3.687610    0.777947  2.000000e+00    3.0    4.0    4.0
# BPXPLS    7361.0   74.893900   13.030056  4.000000e+01   66.0   74.0   82.0
# BPXPULS   9386.0    1.018219    0.133748  1.000000e+00    1.0    1.0    1.0
# BPXPTY    7370.0    1.000678    0.026040  1.000000e+00    1.0    1.0    1.0
# BPXML1    7352.0  146.229597   19.546917  1.100000e+02  130.0  140.0  160.0
# BPXSY1    7147.0  121.164405   19.540831  7.400000e+01  108.0  118.0  130.0
# BPXDI1    7147.0   66.959843   14.448183  5.397605e-79   58.0   68.0   76.0
# BPAEN1    7354.0    2.000000    0.000000  2.000000e+00    2.0    2.0    2.0
# BPXSY2    6876.0  120.081152   18.827997  7.600000e+01  108.0  116.0  130.0
# BPXDI2    6876.0   66.960151   14.223898  5.397605e-79   59.5   68.0   76.0
# BPAEN2    7354.0    1.990209    0.098469  1.000000e+00    2.0    2.0    2.0
# BPXSY3    6759.0  119.120876   18.336841  7.400000e+01  106.0  116.0  128.0
# BPXDI3    6759.0   66.717858   14.429083  5.397605e-79   58.0   68.0   76.0
# BPAEN3    7354.0    1.991297    0.092888  1.000000e+00    2.0    2.0    2.0
# BPXSY4     225.0  127.706667   24.835228  8.000000e+01  110.0  124.0  140.0
# BPXDI4     225.0   71.022222   16.509858  5.397605e-79   62.0   72.0   82.0
# BPAEN4     800.0    1.980000    0.140088  1.000000e+00    2.0    2.0    2.0
#
#              max
# PEASCST1     3.0
# PEASCTM1  1521.0
# PEASCCT1    99.0
# BPXCHR     208.0
# BPQ150A      2.0
# BPQ150B      2.0
# BPQ150C      2.0
# BPQ150D      2.0
# BPAARM       8.0
# BPACSZ       5.0
# BPXPLS     224.0
# BPXPULS      2.0
# BPXPTY       2.0
# BPXML1     240.0
# BPXSY1     230.0
# BPXDI1     116.0
# BPAEN1       2.0
# BPXSY2     220.0
# BPXDI2     122.0
# BPAEN2       2.0
# BPXSY3     222.0
# BPXDI3     120.0
# BPAEN3       2.0
# BPXSY4     214.0
# BPXDI4     118.0
# BPAEN4       2.0

# %%
BPX_Select = BPX.filter(['BPXPLS','BPXSY1','BPXDI1','BPXSY2','BPXDI2','BPXSY3','BPXDI3','BPXSY4','BPXDI4'])

# %%
BPX_Select.describe().T
# Out:
#          count        mean        std           min    25%    50%    75%  \
# BPXPLS  7361.0   74.893900  13.030056  4.000000e+01   66.0   74.0   82.0
# BPXSY1  7147.0  121.164405  19.540831  7.400000e+01  108.0  118.0  130.0
# BPXDI1  7147.0   66.959843  14.448183  5.397605e-79   58.0   68.0   76.0
# BPXSY2  6876.0  120.081152  18.827997  7.600000e+01  108.0  116.0  130.0
# BPXDI2  6876.0   66.960151  14.223898  5.397605e-79   59.5   68.0   76.0
# BPXSY3  6759.0  119.120876  18.336841  7.400000e+01  106.0  116.0  128.0
# BPXDI3  6759.0   66.717858  14.429083  5.397605e-79   58.0   68.0   76.0
# BPXSY4   225.0  127.706667  24.835228  8.000000e+01  110.0  124.0  140.0
# BPXDI4   225.0   71.022222  16.509858  5.397605e-79   62.0   72.0   82.0
#
#           max
# BPXPLS  224.0
# BPXSY1  230.0
# BPXDI1  116.0
# BPXSY2  220.0
# BPXDI2  122.0
# BPXSY3  222.0
# BPXDI3  120.0
# BPXSY4  214.0
# BPXDI4  118.0

# %%
BPX_Select.describe().T.to_csv('BPX_Stats.csv')

# %%
BPX_Select.reset_index()
# Out:
#          SEQN  BPXPLS  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BPXSY3  BPXDI3  BPXSY4  \
# 0     41475.0    66.0   128.0    64.0   122.0    60.0   120.0    58.0     NaN
# 1     41476.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     41477.0    78.0   144.0    60.0   148.0    60.0   142.0    38.0     NaN
# 3     41478.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     41479.0    62.0   112.0    70.0   108.0    66.0   106.0    66.0     NaN
# 5     41480.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6     41481.0    52.0   112.0    62.0   104.0    64.0   112.0    66.0     NaN
# 7     41482.0    76.0   116.0    78.0   114.0    80.0   118.0    72.0     NaN
# 8     41483.0    60.0   110.0    62.0   112.0    56.0   106.0    66.0     NaN
# 9     41484.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10    41485.0    68.0   108.0    44.0   110.0    42.0   108.0    40.0     NaN
# 11    41486.0    62.0   126.0    64.0   120.0    70.0   122.0    66.0     NaN
# 12    41487.0    74.0   120.0    84.0   116.0    80.0   116.0    82.0     NaN
# 13    41488.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14    41489.0    58.0   106.0    66.0   114.0    72.0   108.0    70.0     NaN
# 15    41490.0    72.0   128.0    64.0   134.0    62.0   132.0    62.0     NaN
# 16    41491.0    84.0   120.0    76.0   122.0    78.0   124.0    78.0     NaN
# 17    41492.0    62.0   156.0    94.0   152.0    86.0   140.0    90.0     NaN
# 18    41493.0    68.0   106.0    42.0   118.0    54.0   120.0    52.0     NaN
# 19    41494.0    82.0   120.0    78.0   108.0    64.0   114.0    72.0     NaN
# 20    41495.0    68.0   102.0    64.0    98.0    62.0   100.0    60.0     NaN
# 21    41496.0    78.0   192.0    86.0   192.0    84.0   192.0    88.0     NaN
# 22    41497.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 23    41498.0    60.0   226.0    96.0   204.0    88.0   200.0    90.0     NaN
# 24    41499.0    80.0   116.0    52.0   114.0    68.0   106.0    62.0     NaN
# 25    41500.0   104.0   114.0    58.0   116.0    56.0   114.0    52.0     NaN
# 26    41501.0    60.0   150.0    70.0   144.0    66.0   140.0    68.0     NaN
# 27    41502.0    70.0   124.0    54.0   116.0    68.0   114.0    70.0     NaN
# 28    41503.0    66.0   100.0    52.0   108.0    46.0   102.0    44.0     NaN
# 29    41504.0    72.0   148.0    88.0   146.0    96.0   148.0    94.0     NaN
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 9732  51592.0   102.0   122.0    72.0     NaN     NaN     NaN     NaN     NaN
# 9733  51593.0    70.0   140.0    76.0   140.0    80.0   136.0    78.0     NaN
# 9734  51594.0    78.0   126.0    74.0   128.0    64.0   128.0    62.0     NaN
# 9735  51596.0    62.0   120.0    80.0   142.0    64.0     NaN     NaN     NaN
# 9736  51597.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9737  51598.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9738  51599.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9739  51600.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9740  51601.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9741  51603.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9742  51604.0    74.0   126.0    80.0   126.0    82.0   112.0    76.0     NaN
# 9743  51605.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9744  51606.0    96.0   142.0    90.0   134.0    86.0   136.0    90.0     NaN
# 9745  51607.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9746  51608.0    94.0   124.0    74.0   122.0    78.0   118.0    72.0     NaN
# 9747  51609.0    76.0   104.0    62.0   106.0    70.0   106.0    72.0     NaN
# 9748  51610.0    68.0   118.0    52.0   108.0    48.0   108.0    44.0     NaN
# 9749  51611.0    90.0   116.0    68.0   112.0    64.0   106.0    62.0     NaN
# 9750  51612.0    92.0    76.0    56.0     NaN     NaN     NaN     NaN     NaN
# 9751  51613.0    94.0   114.0    68.0   106.0    70.0   114.0    62.0     NaN
# 9752  51614.0    72.0   116.0    70.0   108.0    72.0   100.0    68.0     NaN
# 9753  51615.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9754  51616.0    74.0   180.0    62.0   168.0    50.0   162.0    46.0     NaN
# 9755  51617.0    68.0   126.0    62.0   120.0    64.0   124.0    66.0     NaN
# 9756  51618.0    78.0   144.0    84.0   136.0    84.0   134.0    80.0     NaN
# 9757  51619.0    54.0   152.0    72.0   150.0    72.0   146.0    74.0     NaN
# 9758  51620.0    58.0    96.0    70.0   126.0    66.0     NaN     NaN     NaN
# 9759  51621.0    72.0   122.0    50.0   120.0    50.0   114.0    44.0     NaN
# 9760  51622.0    68.0   148.0    84.0   144.0    86.0   146.0    86.0     NaN
# 9761  51623.0    70.0   112.0    66.0   116.0    66.0   120.0    68.0     NaN
#
#       BPXDI4
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# ...      ...
# 9732     NaN
# 9733     NaN
# 9734     NaN
# 9735     NaN
# 9736     NaN
# 9737     NaN
# 9738     NaN
# 9739     NaN
# 9740     NaN
# 9741     NaN
# 9742     NaN
# 9743     NaN
# 9744     NaN
# 9745     NaN
# 9746     NaN
# 9747     NaN
# 9748     NaN
# 9749     NaN
# 9750     NaN
# 9751     NaN
# 9752     NaN
# 9753     NaN
# 9754     NaN
# 9755     NaN
# 9756     NaN
# 9757     NaN
# 9758     NaN
# 9759     NaN
# 9760     NaN
# 9761     NaN
#
# [9762 rows x 10 columns]

# %%
BPX_Select.to_csv('Exam_BPX_filter.csv')

# %% [markdown]
# # Processing Column of BPX
#
# ## Blood pressure reading is taken 3 times and if any inconsistency found then even fourth time. Below we -
# ### Provided the description of all 4 readings (Systolic)
# ### merge for mean of all four.
# ### BP readings of age 8 and more had been recorded. All readings are in mm/hg
# ### Reading for systolic cannot be zero and should always be grater then diastolic

# %%
bp_reading1 = BPX['BPXDI1']
print('bp_reading1 shape = ', bp_reading1.shape)
print(bp_reading1.head())
print(bp_reading1.describe())
# Out:
# bp_reading1 shape =  (9762,)
# SEQN
# 41475.0    64.0
# 41476.0     NaN
# 41477.0    60.0
# 41478.0     NaN
# 41479.0    70.0
# Name: BPXDI1, dtype: float64
# count    7.147000e+03
# mean     6.695984e+01
# std      1.444818e+01
# min      5.397605e-79
# 25%      5.800000e+01
# 50%      6.800000e+01
# 75%      7.600000e+01
# max      1.160000e+02
# Name: BPXDI1, dtype: float64

# %%
bp_reading2 = BPX['BPXDI2']
print('bp_reading2 shape = ', bp_reading2.shape)
print(bp_reading2.head())
print(bp_reading2.describe())
# Out:
# bp_reading2 shape =  (9762,)
# SEQN
# 41475.0    60.0
# 41476.0     NaN
# 41477.0    60.0
# 41478.0     NaN
# 41479.0    66.0
# Name: BPXDI2, dtype: float64
# count    6.876000e+03
# mean     6.696015e+01
# std      1.422390e+01
# min      5.397605e-79
# 25%      5.950000e+01
# 50%      6.800000e+01
# 75%      7.600000e+01
# max      1.220000e+02
# Name: BPXDI2, dtype: float64

# %%
bp_reading3 = BPX['BPXDI3']
print('bp_reading3 shape = ', bp_reading3.shape)
print(bp_reading3.head())
print(bp_reading3.describe())
# Out:
# bp_reading3 shape =  (9762,)
# SEQN
# 41475.0    58.0
# 41476.0     NaN
# 41477.0    38.0
# 41478.0     NaN
# 41479.0    66.0
# Name: BPXDI3, dtype: float64
# count    6.759000e+03
# mean     6.671786e+01
# std      1.442908e+01
# min      5.397605e-79
# 25%      5.800000e+01
# 50%      6.800000e+01
# 75%      7.600000e+01
# max      1.200000e+02
# Name: BPXDI3, dtype: float64

# %%
bp_reading4 = BPX['BPXDI4']
print('bp_reading4 shape = ', bp_reading4.shape)
print(bp_reading4.head())
print(bp_reading4.describe())
# Out:
# bp_reading4 shape =  (9762,)
# SEQN
# 41475.0   NaN
# 41476.0   NaN
# 41477.0   NaN
# 41478.0   NaN
# 41479.0   NaN
# Name: BPXDI4, dtype: float64
# count    2.250000e+02
# mean     7.102222e+01
# std      1.650986e+01
# min      5.397605e-79
# 25%      6.200000e+01
# 50%      7.200000e+01
# 75%      8.200000e+01
# max      1.180000e+02
# Name: BPXDI4, dtype: float64

# %%
print('bp_reading1 missing values =  ', bp_reading1.isnull().sum(), 'from ', bp_reading1.shape[0], 'observations')
print('bp_reading2 missing values = ', bp_reading2.isnull().sum(), 'from ', bp_reading2.shape[0], 'observations')
print('bp_reading3 missing values =  ', bp_reading3.isnull().sum(), 'from ', bp_reading3.shape[0], 'observations')
print('bp_reading4 missing values = ', bp_reading4.isnull().sum(), 'from ', bp_reading4.shape[0], 'observations')
# Out:
# bp_reading1 missing values =   2615 from  9762 observations
# bp_reading2 missing values =  2886 from  9762 observations
# bp_reading3 missing values =   3003 from  9762 observations
# bp_reading4 missing values =  9537 from  9762 observations

# %%
bp_reading_all = pd.concat([bp_reading1, bp_reading2,bp_reading3,bp_reading4], axis=1)
print('bp_reading_all shape = ', bp_reading_all.shape)
print(bp_reading_all.head())
# Out:
# bp_reading_all shape =  (9762, 4)
#          BPXDI1  BPXDI2  BPXDI3  BPXDI4
# SEQN
# 41475.0    64.0    60.0    58.0     NaN
# 41476.0     NaN     NaN     NaN     NaN
# 41477.0    60.0    60.0    38.0     NaN
# 41478.0     NaN     NaN     NaN     NaN
# 41479.0    70.0    66.0    66.0     NaN

# %%
bp_reading_all_mean = bp_reading_all.mean(axis=1, skipna=1)
print('Type of bp_reading_all_mean = ', bp_reading_all_mean.dtype)
print(bp_reading_all_mean.name)
bp_reading_all_mean.name = 'Total_bp_mean'
print(bp_reading_all_mean.name)
bp_reading_all_mean.isnull().sum()
# Out:
# Type of bp_reading_all_mean =  float64
# None
# Total_bp_mean
# 2412

# %%
bp_mean_all = pd.concat([bp_reading_all, bp_reading_all_mean], axis=1)
print('bp_mean_all shape = ', bp_mean_all.shape)
print(bp_mean_all.head())
# Out:
# bp_mean_all shape =  (9762, 5)
#          BPXDI1  BPXDI2  BPXDI3  BPXDI4  Total_bp_mean
# SEQN
# 41475.0    64.0    60.0    58.0     NaN      60.666667
# 41476.0     NaN     NaN     NaN     NaN            NaN
# 41477.0    60.0    60.0    38.0     NaN      52.666667
# 41478.0     NaN     NaN     NaN     NaN            NaN
# 41479.0    70.0    66.0    66.0     NaN      67.333333
