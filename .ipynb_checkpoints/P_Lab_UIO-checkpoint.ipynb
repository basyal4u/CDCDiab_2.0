# %% [markdown]
# #  Processing Laboratory - Iodine (UIO) file

# %%
import numpy as np
import pandas as pd
import glob 
import os
import sys

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Code'

# %%
path = 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab'
allFiles = glob.glob(os.path.join(path,"*.XPT"))
print(allFiles)
# Out:
# ['C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\ALB_CR_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\APOB_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\BIOPRO_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CARB_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CBC_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CHLMDA_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\COTNAL_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CRP_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\DEET_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\EPH_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\FASTQX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\FERTIN_E.XPT', 'C:\
# ...

# %%
UIO = pd.read_sas('C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\UIO_E.XPT', index='SEQN')
UIO.shape
# Out:
# (8132, 2)

# %%
A = set(UIO.columns)
print(sorted(A))
# Out:
# ['URXUCR', 'URXUIO']

# %%
UIO.describe().T
# Out:
#          count        mean          std  min   25%     50%      75%       max
# URXUIO  7506.0  411.391873  9038.029110  2.1  95.0  165.45  284.475  762010.0
# URXUCR  7878.0  124.304265    77.817509  3.0  66.0  111.00  166.000     724.0

# %%
UIO.reset_index()
# Out:
#          SEQN  URXUIO  URXUCR
# 0     41475.0   210.1    45.0
# 1     41476.0   244.6    72.0
# 2     41477.0   364.3   135.0
# 3     41479.0   224.3   124.0
# 4     41480.0   153.5    33.0
# 5     41481.0   380.4   366.0
# 6     41482.0   969.7   130.0
# 7     41483.0    75.1    58.0
# 8     41485.0    61.2    69.0
# 9     41486.0   178.1    72.0
# 10    41487.0     NaN    81.0
# 11    41489.0    88.6    91.0
# 12    41490.0    57.9    22.0
# 13    41491.0   187.1    78.0
# 14    41492.0     NaN    49.0
# 15    41493.0    34.3    51.0
# 16    41494.0   358.6   257.0
# 17    41495.0   193.3    32.0
# 18    41496.0     NaN     NaN
# 19    41498.0   172.1   137.0
# 20    41499.0  1411.4   169.0
# 21    41500.0   361.7   194.0
# 22    41501.0   182.3   189.0
# 23    41502.0   113.6   136.0
# 24    41503.0   625.1   233.0
# 25    41504.0   115.5    95.0
# 26    41506.0    86.1   118.0
# 27    41507.0   411.7   103.0
# 28    41509.0    49.6    40.0
# 29    41510.0   200.7   134.0
# ...

# %%
UIO.to_csv('UIO_Lab_filter.csv')

# %% [markdown]
# # Processing Column of UIO

# %%
# Iodine in urine ug/l
UIO_reading1 = UIO['URXUIO']
print('UIO_reading1 shape = ', UIO_reading1.shape)
print(UIO_reading1.head())
print(UIO_reading1.describe())
# Out:
# UIO_reading1 shape =  (8132,)
# SEQN
# 41475.0    210.1
# 41476.0    244.6
# 41477.0    364.3
# 41479.0    224.3
# 41480.0    153.5
# Name: URXUIO, dtype: float64
# count      7506.000000
# mean        411.391873
# std        9038.029110
# min           2.100000
# 25%          95.000000
# 50%         165.450000
# 75%         284.475000
# max      762010.000000
# Name: URXUIO, dtype: float64

# %%
# Creatinine in urine mg/l
UIO_reading2 = UIO['URXUCR']
print('UIO_reading2 shape = ', UIO_reading2.shape)
print(UIO_reading2.head())
print(UIO_reading2.describe())
# Out:
# UIO_reading2 shape =  (8132,)
# SEQN
# 41475.0     45.0
# 41476.0     72.0
# 41477.0    135.0
# 41479.0    124.0
# 41480.0     33.0
# Name: URXUCR, dtype: float64
# count    7878.000000
# mean      124.304265
# std        77.817509
# min         3.000000
# 25%        66.000000
# 50%       111.000000
# 75%       166.000000
# max       724.000000
# Name: URXUCR, dtype: float64

# %%
print('UIO_reading1 missing values =  ', UIO_reading1.isnull().sum(), 'from ', UIO_reading1.shape[0], 'observations')
print('UIO_reading2 missing values =  ', UIO_reading2.isnull().sum(), 'from ', UIO_reading2.shape[0], 'observations')
# Out:
# UIO_reading1 missing values =   626 from  8132 observations
# UIO_reading2 missing values =   254 from  8132 observations
