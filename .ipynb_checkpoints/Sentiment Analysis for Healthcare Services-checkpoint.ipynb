# %%
import os
import sys
import nltk 
import nltk.corpus

# %%
from textblob import TextBlob
import tweepy
import matplotlib.pyplot as plt

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
test = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
test
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in test[:500]:
    print(word, sep=' ',end=' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Ba
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
type(test)
# Out:
# nltk.corpus.reader.util.StreamBackedCorpusView

# %%
consumer_key = "wysCoJMQEtl1bQImCVhkO2aAj"
consumer_secret = "9diHewMs57uvXBnct0g5RYjEBO2JLQ1GAzWyIuYLqYzgJFl3md"
access_token = "948782674046406656-jEvvxOv0VKRocmA4vno7aYhcpAi6kwG"
access_token_secret = "XSOdfmYjAEmOAlkrcY2yjzV0B3DU6S4eMazLquXxQPO6g"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %%
public_tweet = api.search('us healthcare')
print(public_tweet)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000024D5297A860>, _json={'created_at': 'Mon Feb 25 09:49:31 +0000 2019', 'id': 1099969633023598592, 'id_str': '1099969633023598592', 'text': 'RT @EricTopol: The #US now spends more than $11,000 per person for healthcare, while the #UK ~$4,000. Yet life expectancy has declined in t…', 'truncated': False, 'entities': {'hashtags': [{'text': 'US', 'indices': [19, 22]}, {'text': 'UK', 'indices': [89, 92]}], 'symbols': [], 'user_mentions': [{'screen_name': 'EricTopol', 'name': 'Eric Topol', 'id': 86626845, 'id_str': '86626845', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 28835588, 'id_str': '28835588', 'name': 'Andrew Heagle'
# ...

# %%
type("public_tweet")
# Out:
# str

# %%
for tweet in public_tweet:
    print(tweet.text)
# Out:
# RT @EricTopol: The #US now spends more than $11,000 per person for healthcare, while the #UK ~$4,000. Yet life expectancy has declined in t…
# RT @tedlieu: Last Nov, @GOP campaigned on the Wall of @realDonaldTrump. Dems campaigned on healthcare, infrastructure &amp; rooting out corrupt…
# If you need to give your #body full of #energy. So come and join RGHC No 1 Healthcare Centre in Ludhiana. Gives you… https://t.co/ErfUp8WZGT
# ☀ Hiring: #Earn Extra Cash Driving. Pharmacy Technician, Drive With Lyft! !
# #EastLosAngeles #healthcare… https://t.co/oUKFKy8GDb
# RT @DogginTrump: @realDonaldTrump @KatiePavlich We Suburban women don’t want anything to do with you or the GOP. You tried taking our famil…
# RT @EricTopol: The #US now spends more than $11,000 per person for healthcare, while the #UK ~$4,000. Yet life expectancy has declined in t…
# ☀ Hiring: #RESEARCH COORDINATOR (TEMPORARY PROJECT APPT)
# #healthcare #HospitalJobs #MedicalResearch #Seattle… https://t.co/xBRGE9vWlb
# ...

# %%
for tweet in public_tweet:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# RT @EricTopol: The #US now spends more than $11,000 per person for healthcare, while the #UK ~$4,000. Yet life expectancy has declined in t…
# Sentiment(polarity=0.5, subjectivity=0.5)
# RT @tedlieu: Last Nov, @GOP campaigned on the Wall of @realDonaldTrump. Dems campaigned on healthcare, infrastructure &amp; rooting out corrupt…
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# If you need to give your #body full of #energy. So come and join RGHC No 1 Healthcare Centre in Ludhiana. Gives you… https://t.co/ErfUp8WZGT
# Sentiment(polarity=0.35, subjectivity=0.55)
# ☀ Hiring: #Earn Extra Cash Driving. Pharmacy Technician, Drive With Lyft! !
# #EastLosAngeles #healthcare… https://t.co/oUKFKy8GDb
# Sentiment(polarity=0.0, subjectivity=0.1)
# RT @DogginTrump: @realDonaldTrump @KatiePavlich We Suburban women don’t want anything to do with you or the GOP. You tried taking our famil…
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
for tweet in public_tweet:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    if analysis.sentiment[0]>0:
       print ('Positive')
    elif analysis.sentiment[0]<0:
       print ('Negative')
    else:
       print ('Neutral')
# Out:
# RT @EricTopol: The #US now spends more than $11,000 per person for healthcare, while the #UK ~$4,000. Yet life expectancy has declined in t…
# Sentiment(polarity=0.5, subjectivity=0.5)
# Positive
# RT @tedlieu: Last Nov, @GOP campaigned on the Wall of @realDonaldTrump. Dems campaigned on healthcare, infrastructure &amp; rooting out corrupt…
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Neutral
# If you need to give your #body full of #energy. So come and join RGHC No 1 Healthcare Centre in Ludhiana. Gives you… https://t.co/ErfUp8WZGT
# Sentiment(polarity=0.35, subjectivity=0.55)
# Positive
# ☀ Hiring: #Earn Extra Cash Driving. Pharmacy Technician, Drive With Lyft! !
# #EastLosAngeles #healthcare… https://t.co/oUKFKy8GDb
# Sentiment(polarity=0.0, subjectivity=0.1)
# Neutral
# RT @DogginTrump: @realDonaldTrump @KatiePavlich We Suburban women don’t want anything to do with you or the GOP. You tried taking our famil…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# ...
