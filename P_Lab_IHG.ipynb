# %% [markdown]
# #  Processing Laboratory - Mercury_Inorganic_Blood(IHG) file

# %%
import numpy as np
import pandas as pd
import glob 
import os
import sys

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Code'

# %%
path = 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab'
allFiles = glob.glob(os.path.join(path,"*.XPT"))
print(allFiles)
# Out:
# ['C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\ALB_CR_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\APOB_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\BIOPRO_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CARB_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CBC_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CHLMDA_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\COTNAL_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\CRP_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\DEET_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\EPH_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\FASTQX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\FERTIN_E.XPT', 'C:\
# ...

# %%
IHG = pd.read_sas('C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Lab\\IHG_E.XPT', index='SEQN')
IHG.shape
# Out:
# (9307, 3)

# %%
A = set(IHG.columns)
print(sorted(A))
# Out:
# ['LBDIHGLC', 'LBDIHGSI', 'LBXIHG']

# %%
IHG.describe().T
# Out:
#            count      mean       std           min   25%   50%   75%    max
# LBXIHG    8162.0  0.318204  0.233392  2.500000e-01  0.25  0.25  0.25  14.00
# LBDIHGSI  8162.0  1.590051  1.164026  1.250000e+00  1.25  1.25  1.25  69.86
# LBDIHGLC  8162.0  0.772115  0.419494  5.397605e-79  1.00  1.00  1.00   1.00

# %%
IHG.reset_index()
# Out:
#          SEQN  LBXIHG  LBDIHGSI      LBDIHGLC
# 0     41475.0    0.25      1.25  1.000000e+00
# 1     41476.0    0.25      1.25  1.000000e+00
# 2     41477.0    0.25      1.25  1.000000e+00
# 3     41478.0     NaN       NaN           NaN
# 4     41479.0    0.25      1.25  1.000000e+00
# 5     41480.0     NaN       NaN           NaN
# 6     41481.0     NaN       NaN           NaN
# 7     41482.0    0.25      1.25  1.000000e+00
# 8     41483.0    0.25      1.25  1.000000e+00
# 9     41485.0    0.25      1.25  1.000000e+00
# 10    41486.0    0.25      1.25  1.000000e+00
# 11    41487.0    0.25      1.25  1.000000e+00
# 12    41488.0    0.25      1.25  1.000000e+00
# 13    41489.0    0.25      1.25  1.000000e+00
# 14    41490.0    0.45      2.25  5.397605e-79
# 15    41491.0    0.60      2.99  5.397605e-79
# 16    41492.0    0.25      1.25  1.000000e+00
# 17    41493.0    0.25      1.25  1.000000e+00
# 18    41494.0    0.25      1.25  1.000000e+00
# ...

# %%
IHG.to_csv('IHG_Lab_filter.csv')

# %% [markdown]
# # Processing Column of IHG

# %%
# Inorganic mercury ug/l
IHG_reading1 = IHG['LBXIHG']
print('IHG_reading1 shape = ', IHG_reading1.shape)
print(IHG_reading1.head())
print(IHG_reading1.describe())
# Out:
# IHG_reading1 shape =  (9307,)
# SEQN
# 41475.0    0.25
# 41476.0    0.25
# 41477.0    0.25
# 41478.0     NaN
# 41479.0    0.25
# Name: LBXIHG, dtype: float64
# count    8162.000000
# mean        0.318204
# std         0.233392
# min         0.250000
# 25%         0.250000
# 50%         0.250000
# 75%         0.250000
# max        14.000000
# Name: LBXIHG, dtype: float64

# %%
# Inorganic mercury comment yes or no
IHG_reading2 = IHG['LBDIHGLC']
print('IHG_reading2 shape = ', IHG_reading2.shape)
print(IHG_reading2.head())
print(IHG_reading2.describe())
# Out:
# IHG_reading2 shape =  (9307,)
# SEQN
# 41475.0    1.0
# 41476.0    1.0
# 41477.0    1.0
# 41478.0    NaN
# 41479.0    1.0
# Name: LBDIHGLC, dtype: float64
# count    8.162000e+03
# mean     7.721147e-01
# std      4.194939e-01
# min      5.397605e-79
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: LBDIHGLC, dtype: float64

# %%
print('IHG_reading1 missing values =  ', IHG_reading1.isnull().sum(), 'from ', IHG_reading1.shape[0], 'observations')
print('IHG_reading2 missing values =  ', IHG_reading2.isnull().sum(), 'from ', IHG_reading2.shape[0], 'observations')
# Out:
# IHG_reading1 missing values =   1145 from  9307 observations
# IHG_reading2 missing values =   1145 from  9307 observations

# %%
IHG.describe()
# Out:
#             LBXIHG     LBDIHGSI      LBDIHGLC
# count  8162.000000  8162.000000  8.162000e+03
# mean      0.318204     1.590051  7.721147e-01
# std       0.233392     1.164026  4.194939e-01
# min       0.250000     1.250000  5.397605e-79
# 25%       0.250000     1.250000  1.000000e+00
# 50%       0.250000     1.250000  1.000000e+00
# 75%       0.250000     1.250000  1.000000e+00
# max      14.000000    69.860000  1.000000e+00
