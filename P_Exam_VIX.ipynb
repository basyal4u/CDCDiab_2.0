# %% [markdown]
# #  Processing Examination - Vision (VIX)

# %%
import numpy as np
import pandas as pd
import glob 
import os
import sys

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Code'

# %%
path = 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination'
allFiles = glob.glob(os.path.join(path,"*.XPT"))
print(allFiles)
#%cd /Users/elgayaro/Main/Research/Healthcare/CDC-NHANES/Data/07-08/Examination -Omar
# Out:
# ['C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUXAR_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUXTYM_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\AUX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\BMX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\BPX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\DXXFEM_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\DXXSPN_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\ENX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OHX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OPXFDT_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\OPXRET_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\SPX_E.XPT', 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\VIX_E.XPT']

# %%
#allFiles = glob.glob(os.path.join('.',"*.XPT")) Omar
#print(allFiles) Omar
VIX = pd.read_sas('C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab_2.0\\Data\\07-08\\Examination\\VIX_E.XPT', index='SEQN')
VIX.shape
# Out:
# (6917, 56)

# %%
A = set(VIX.columns)
print(sorted(A))
# Out:
# ['VIDLOVA', 'VIDLVA', 'VIDOLFM', 'VIDORFM', 'VIDROVA', 'VIDRVA', 'VIQ110', 'VIQ121', 'VIQ130', 'VIQ141', 'VIQ150', 'VIQ160', 'VIQ170', 'VIQ180', 'VIQ191', 'VIQ200', 'VIQ211', 'VIQ220', 'VIQ230', 'VIQ240', 'VIQ250', 'VIXKLCD', 'VIXKLCG', 'VIXKLD1', 'VIXKLD2', 'VIXKLDM', 'VIXKLG1', 'VIXKLG2', 'VIXKLM1', 'VIXKLM2', 'VIXKLMM', 'VIXKRCD', 'VIXKRCG', 'VIXKRD1', 'VIXKRD2', 'VIXKRDM', 'VIXKRG1', 'VIXKRG2', 'VIXKRM1', 'VIXKRM2', 'VIXKRMM', 'VIXNC1', 'VIXNC2', 'VIXOCMT', 'VIXOLAM', 'VIXOLCM', 'VIXOLSM', 'VIXORAM', 'VIXORCM', 'VIXORSM', 'VIXPLA', 'VIXPLC', 'VIXPLS', 'VIXPRA', 'VIXPRC', 'VIXPRS']

# %%
VIX.dtypes
# Out:
# VIQ110     float64
# VIQ121     float64
# VIQ130     float64
# VIQ141     float64
# VIQ150     float64
# VIQ160     float64
# VIQ170     float64
# VIXNC1     float64
# VIXNC2     float64
# VIQ180     float64
# VIQ191     float64
# VIQ200     float64
# VIQ211     float64
# VIQ220     float64
# VIQ230     float64
# VIQ240     float64
# VIQ250     float64
# VIXPRS     float64
# VIXPRC     float64
# VIXPRA     float64
# VIXPLS     float64
# VIXPLC     float64
# VIXPLA     float64
# VIXOCMT    float64
# VIXORSM    float64
# VIXORCM    float64
# VIXORAM    float64
# VIDORFM    float64
# VIXOLSM    float64
# VIXOLCM    float64
# VIXOLAM    float64
# VIDOLFM    float64
# VIXKRM1    float64
# VIXKRD1    float64
# VIXKRG1    float64
# VIXKRM2    float64
# VIXKRD2    float64
# VIXKRG2    float64
# VIXKRMM    float64
# VIXKRDM    float64
# VIXKRCD    float64
# VIXKRCG    float64
# VIXKLM1    float64
# VIXKLD1    float64
# VIXKLG1    float64
# VIXKLM2    float64
# VIXKLD2    float64
# VIXKLG2    float64
# VIXKLMM    float64
# VIXKLDM    float64
# VIXKLCD    float64
# VIXKLCG    float64
# VIDRVA     float64
# VIDLVA     float64
# VIDROVA    float64
# VIDLOVA    float64
# dtype: object

# %%
VIX.head()
# Out:
#          VIQ110  VIQ121  VIQ130  VIQ141  VIQ150  VIQ160  VIQ170  VIXNC1  \
# SEQN
# 41475.0     2.0     NaN     2.0     NaN     1.0     1.0     1.0     5.0
# 41477.0     2.0     NaN     2.0     NaN     1.0     1.0     1.0     5.0
# 41479.0     2.0     NaN     2.0     NaN     2.0     NaN     NaN     3.0
# 41481.0     2.0     NaN     2.0     NaN     NaN     NaN     NaN     NaN
# 41482.0     2.0     NaN     2.0     NaN     1.0     1.0     1.0     5.0
#
#          VIXNC2  VIQ180   ...     VIXKLD2  VIXKLG2  VIXKLMM  VIXKLDM  VIXKLCD  \
# SEQN                      ...
# 41475.0    15.0     2.0   ...       44.25     94.0     7.72    43.75     1.00
# 41477.0    13.0     2.0   ...       44.75     46.0     7.63    44.25     0.75
# 41479.0    15.0     2.0   ...       45.00     83.0     7.58    44.50     1.00
# 41481.0     NaN     2.0   ...       42.50    100.0     7.97    42.25     0.25
# 41482.0    18.0     2.0   ...       42.00    154.0     8.10    41.75     0.50
#
#          VIXKLCG  VIDRVA  VIDLVA  VIDROVA  VIDLOVA
# SEQN
# 41475.0     94.0    25.0    25.0      NaN      NaN
# 41477.0     46.0    25.0    25.0      NaN      NaN
# 41479.0     83.0    20.0    25.0      NaN      NaN
# 41481.0    100.0    20.0    20.0      NaN      NaN
# 41482.0    154.0    25.0    20.0      NaN      NaN
#
# [5 rows x 56 columns]

# %%
VIX.shape
# Out:
# (6917, 56)

# %%
VIX_Select = VIX.filter(['VIQ180','VIQ200','VIQ220','VIXORSM','VIDORFM','VIDOLFM','VIDRVA','VIDLVA'])

# %%
VIX_Select.describe().T
# Out:
#           count       mean        std   min   25%   50%    75%    max
# VIQ180   6527.0   2.006435   0.406379   1.0   2.0   2.0   2.00    9.0
# VIQ200   6527.0   1.929983   0.399395   1.0   2.0   2.0   2.00    9.0
# VIQ220   6527.0   1.547265   0.523017   1.0   1.0   2.0   2.00    9.0
# VIXORSM  6506.0   2.742003  17.765980 -18.0  -1.5  -0.5   0.25   88.0
# VIDORFM  6291.0   8.663996   0.694078   5.0   8.7   9.0   9.00    9.0
# VIDOLFM  6295.0   8.660508   0.702875   5.0   8.7   9.0   9.00    9.0
# VIDRVA   6441.0  39.225586  67.017101  20.0  20.0  25.0  30.00  666.0
# VIDLVA   6452.0  39.400496  68.627218  20.0  20.0  25.0  30.00  666.0

# %%
VIX_Select.describe().T.to_csv('VIX.csv')

# %%
VIX_Select.reset_index()
# Out:
#          SEQN  VIQ180  VIQ200  VIQ220       VIXORSM  VIDORFM  VIDOLFM  VIDRVA  \
# 0     41475.0     2.0     2.0     2.0 -1.000000e+00      9.0      9.0    25.0
# 1     41477.0     2.0     2.0     2.0  5.397605e-79      7.7      7.3    25.0
# 2     41479.0     2.0     2.0     2.0  5.397605e-79      9.0      8.3    20.0
# 3     41481.0     2.0     2.0     2.0  7.500000e-01      9.0      9.0    20.0
# 4     41482.0     2.0     2.0     1.0  7.500000e-01      9.0      8.0    25.0
# 5     41483.0     2.0     2.0     1.0 -5.000000e-01      8.7      9.0    20.0
# 6     41485.0     2.0     2.0     2.0 -5.000000e-01      9.0      9.0    20.0
# 7     41486.0     2.0     2.0     2.0 -2.500000e-01      8.7      7.7    25.0
# 8     41487.0     2.0     2.0     2.0  2.500000e-01      9.0      9.0    20.0
# 9     41489.0     2.0     2.0     1.0 -2.000000e+00      9.0      9.0    20.0
# 10    41490.0     2.0     2.0     2.0  2.000000e+00      8.7      9.0    80.0
# 11    41492.0     2.0     1.0     2.0 -5.000000e-01      9.0      9.0    25.0
# 12    41493.0     2.0     1.0     2.0 -1.000000e+00      8.3      6.5    50.0
# 13    41494.0     2.0     2.0     2.0 -2.500000e-01      9.0      9.0    25.0
# 14    41495.0     2.0     2.0     1.0  1.250000e+00      9.0      8.7    20.0
# 15    41496.0     2.0     2.0     1.0  3.250000e+00      9.0      8.7    20.0
# 16    41498.0     2.0     2.0     2.0  2.500000e-01      7.0      8.3    25.0
# 17    41499.0     2.0     2.0     2.0 -5.000000e-01      8.3      9.0    20.0
# 18    41500.0     2.0     2.0     2.0 -2.500000e-01      9.0      9.0    60.0
# 19    41501.0     2.0     2.0     1.0  2.500000e-01      8.3      8.7    30.0
# 20    41502.0     2.0     2.0     2.0 -5.000000e-01      9.0      9.0    20.0
# 21    41503.0     2.0     2.0     2.0 -2.500000e-01      9.0      9.0    20.0
# 22    41504.0     2.0     2.0     2.0 -5.000000e-01      9.0      9.0    20.0
# 23    41506.0     2.0     1.0     1.0 -2.000000e+00      9.0      NaN    20.0
# 24    41509.0     2.0     2.0     2.0  1.000000e+00      8.7      8.0    25.0
# 25    41510.0     2.0     2.0     2.0  5.397605e-79      9.0      9.0    20.0
# 26    41511.0     2.0     2.0     2.0 -2.500000e-01      9.0      9.0    50.0
# 27    41512.0     NaN     NaN     NaN           NaN      NaN      NaN     NaN
# 28    41513.0     2.0     1.0     1.0  8.800000e+01      NaN      NaN     NaN
# 29    41514.0     2.0     1.0     1.0  8.800000e+01      NaN      8.0    25.0
# ...       ...     ...     ...     ...           ...      ...      ...     ...
# 6887  51583.0     2.0     1.0     2.0  8.800000e+01      NaN      NaN    20.0
# 6888  51584.0     2.0     2.0     1.0  1.250000e+00      9.0      9.0    25.0
# 6889  51585.0     2.0     2.0     2.0  1.000000e+00      8.3      6.3    60.0
# 6890  51587.0     2.0     2.0     1.0 -1.750000e+00      9.0      9.0    20.0
# 6891  51588.0     2.0     2.0     1.0 -1.500000e+00      9.0      8.7    50.0
# 6892  51589.0     2.0     2.0     1.0 -5.250000e+00      9.0      9.0    20.0
# 6893  51590.0     2.0     2.0     2.0 -5.000000e-01      9.0      9.0    25.0
# 6894  51591.0     2.0     2.0     1.0 -1.100000e+01      9.0      8.0    50.0
# 6895  51592.0     2.0     2.0     1.0  7.500000e-01      8.7      8.3    25.0
# 6896  51593.0     2.0     2.0     1.0 -7.500000e-01      9.0      9.0    20.0
# 6897  51594.0     2.0     2.0     2.0 -7.500000e-01      9.0      9.0    30.0
# 6898  51596.0     2.0     2.0     2.0  5.397605e-79      7.7      5.3    25.0
# 6899  51603.0     NaN     NaN     NaN           NaN      NaN      NaN     NaN
# 6900  51604.0     2.0     2.0     2.0  5.000000e-01      9.0      9.0    25.0
# 6901  51606.0     2.0     2.0     1.0 -1.250000e+00      8.3      6.0    25.0
# 6902  51608.0     2.0     2.0     2.0 -2.500000e-01      9.0      8.7    20.0
# 6903  51609.0     2.0     2.0     1.0 -5.000000e-01      9.0      9.0    50.0
# 6904  51610.0     1.0     2.0     2.0 -7.500000e-01      9.0      8.7    25.0
# 6905  51611.0     2.0     2.0     1.0 -8.500000e+00      8.3      8.7    25.0
# 6906  51613.0     2.0     2.0     1.0 -1.250000e+00      9.0      9.0    20.0
# 6907  51614.0     2.0     2.0     1.0 -2.500000e-01      9.0      9.0    20.0
# 6908  51615.0     2.0     1.0     1.0 -5.000000e+00      8.0      9.0    40.0
# 6909  51616.0     2.0     2.0     1.0 -2.750000e+00      8.7      8.3    25.0
# 6910  51617.0     2.0     2.0     1.0  1.000000e+00      9.0      7.7    40.0
# 6911  51618.0     2.0     2.0     1.0 -6.500000e+00      8.0      9.0    25.0
# 6912  51619.0     2.0     2.0     1.0  1.000000e+00      9.0      9.0    20.0
# 6913  51620.0     2.0     2.0     2.0 -2.500000e-01      8.3      9.0    20.0
# 6914  51621.0     2.0     2.0     2.0 -5.000000e-01      8.7      9.0    25.0
# 6915  51622.0     2.0     2.0     2.0 -2.500000e-01      9.0      9.0    30.0
# 6916  51623.0     2.0     2.0     1.0  1.750000e+00      8.7      5.3   200.0
#
#       VIDLVA
# 0       25.0
# 1       25.0
# 2       25.0
# 3       20.0
# 4       20.0
# 5       20.0
# 6       20.0
# 7       50.0
# 8       20.0
# 9       20.0
# 10      40.0
# 11      50.0
# 12      20.0
# 13      25.0
# 14      20.0
# 15      25.0
# 16      25.0
# 17      20.0
# 18      60.0
# 19      25.0
# 20      25.0
# 21      25.0
# 22      20.0
# 23      25.0
# 24      20.0
# 25      20.0
# 26      50.0
# 27       NaN
# 28      30.0
# 29      30.0
# ...      ...
# 6887    20.0
# 6888    20.0
# 6889    40.0
# 6890    20.0
# 6891    60.0
# 6892    20.0
# 6893    20.0
# 6894    80.0
# 6895    20.0
# 6896    30.0
# 6897    25.0
# 6898    20.0
# 6899     NaN
# 6900    30.0
# 6901    40.0
# 6902    20.0
# 6903    50.0
# 6904    40.0
# 6905    25.0
# 6906    30.0
# 6907    25.0
# 6908    30.0
# 6909    20.0
# 6910    25.0
# 6911    25.0
# 6912    20.0
# 6913    20.0
# 6914    25.0
# 6915    30.0
# 6916   200.0
#
# [6917 rows x 9 columns]

# %%
VIX_Select.to_csv('Exam_VIX_filter.csv')

# %% [markdown]
# # Processing Column of VIX (Vision) file

# %%
VIX_reading1 = VIX['VIQ150']
print('VIX_reading1 shape = ', VIX_reading1.shape)
print(VIX_reading1.head())
print(VIX_reading1.describe())
# Out:
# VIX_reading1 shape =  (6917,)
# SEQN
# 41475.0    1.0
# 41477.0    1.0
# 41479.0    2.0
# 41481.0    NaN
# 41482.0    1.0
# Name: VIQ150, dtype: float64
# count    2788.000000
# mean        1.151363
# std         0.434486
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         9.000000
# Name: VIQ150, dtype: float64

# %%
VIX_reading2 = VIX['VIQ220']
print('VIX_reading2 shape = ', VIX_reading2.shape)
print(VIX_reading2.head())
print(VIX_reading2.describe())
# Out:
# VIX_reading2 shape =  (6917,)
# SEQN
# 41475.0    2.0
# 41477.0    2.0
# 41479.0    2.0
# 41481.0    2.0
# 41482.0    1.0
# Name: VIQ220, dtype: float64
# count    6527.000000
# mean        1.547265
# std         0.523017
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         9.000000
# Name: VIQ220, dtype: float64

# %%
print('VIX_reading1 missing values =  ', VIX_reading1.isnull().sum(), 'from ', VIX_reading1.shape[0], 'observations')
print('VIX_reading2 missing values = ', VIX_reading2.isnull().sum(), 'from ', VIX_reading2.shape[0], 'observations')
# Out:
# VIX_reading1 missing values =   4129 from  6917 observations
# VIX_reading2 missing values =  390 from  6917 observations

# %%
VIX_reading_all = pd.concat([VIX_reading1, VIX_reading2], axis=1)
print('VIX_reading_all shape = ', VIX_reading_all.shape)
print(VIX_reading_all.head())
# Out:
# VIX_reading_all shape =  (6917, 2)
#          VIQ150  VIQ220
# SEQN
# 41475.0     1.0     2.0
# 41477.0     1.0     2.0
# 41479.0     2.0     2.0
# 41481.0     NaN     2.0
# 41482.0     1.0     1.0

# %%
VIX_reading_all_mean = VIX_reading_all.mean(axis=1, skipna=1)
print('Type of VIX_reading_all_mean = ', VIX_reading_all_mean.dtype)
print(VIX_reading_all_mean.name)
VIX_reading_all_mean.name = 'Total_VIX_mean'
print(VIX_reading_all_mean.name)
VIX_reading_all_mean.isnull().sum()
# Out:
# Type of VIX_reading_all_mean =  float64
# None
# Total_VIX_mean
# 389

# %%
VIX_mean_all = pd.concat([VIX_reading_all, VIX_reading_all_mean], axis=1)
print('VIX_mean_all shape = ', VIX_mean_all.shape)
print(VIX_mean_all.head())
# Out:
# VIX_mean_all shape =  (6917, 3)
#          VIQ150  VIQ220  Total_VIX_mean
# SEQN
# 41475.0     1.0     2.0             1.5
# 41477.0     1.0     2.0             1.5
# 41479.0     2.0     2.0             2.0
# 41481.0     NaN     2.0             2.0
# 41482.0     1.0     1.0             1.0
